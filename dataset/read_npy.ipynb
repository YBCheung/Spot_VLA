# %%
print(actual_data['arm_poses'][:5])
# Out:
# [[ 6.01109624e-01 -5.14435349e-04  3.00669074e-01  2.57284450e-03
#   -5.09559317e-03 -8.39427055e-04  9.99983311e-01  9.82457428e+01]
#  [ 6.01442456e-01  2.02586729e-04  3.02058846e-01  7.20095867e-03
#   -7.30906753e-03  4.24735015e-04  9.99947309e-01  9.82419281e+01]
#  [ 6.02292597e-01  2.63463310e-03  3.07810068e-01  1.03582898e-02
#   -1.24669932e-02  6.23614946e-03  9.99849200e-01  9.82556610e+01]
#  [ 6.04836166e-01  6.26991224e-03  3.19224805e-01  7.51527026e-03
#   -1.61945317e-02  1.59481838e-02  9.99713421e-01  9.82518539e+01]
#  [ 6.07377887e-01  8.21604952e-03  3.25922847e-01  3.92878894e-03
#   -1.82425231e-02  2.29245238e-02  9.99563038e-01  9.82549057e+01]]

# %%
# Optional: Inspect the data type and shape
delta = np.diff(actual_data['timestamps'])
print("\nData type:", 1/delta[:10])
# Out:
# Data type: [7.23188281 7.60692082 6.66654587 7.33000821 7.11290796 7.05364858
#  8.19826078 7.70585393 7.25562729 7.70581146]

# %%
import numpy as np
import cv2
import psutil
import tracemalloc
import os
import gc

def monitor_memory():
    """Returns the current memory usage in MB."""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 * 1024)

def lazy_data_loader(npz_file, video_file):
    """Lazy loader for arm_pose, frame, and timestep."""
    # Load the .npz file with memory mapping
    data = np.load(npz_file, mmap_mode="r")
    arm_poses = data["arm_poses"]
    timesteps = data["timestamps"]

    # Open the video file
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        raise ValueError("Unable to open video file.")

    # Yield data lazily
    try:
        for i in range(len(arm_poses)):
            ret, frame = cap.read()
            if not ret:
                raise ValueError("Video ended prematurely.")
            
            yield timesteps[i], arm_poses[i], frame

    finally:
        cap.release()

# Example usage
def main(npz_file, video_file):
    datas = []
    loader = lazy_data_loader(npz_file, video_file)
    for i, (timestep, arm_pose, frame) in enumerate(loader):
        
        # Example: Process the frame
        cv2.imshow("Frame", frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):  # Press 'q' to quit
            break

        # release the memory
        # it's important for memory release if stored in a list. 
        # if use lazy loaded data with yield, no need for release, as generater do not store data to memory.
        # instead, the data produced by yield is immediately passed to the consumer. 
        # it's up to the caller to store, process and release the memory. 
        # it can be done by set to None, then gc.collect(); 
        # or, by overwriting to the same addr. #
        
        datas.append([timestep, arm_pose, frame])
        datas[i] = None  
        if i % 10 == 0:  # Check memory every 10 iterations
            print(f"Iteration {i}, Memory Usage: {monitor_memory():.2f} MB")
        
        if i % 200 == 0:
            gc.collect()  # Force garbage collection
            print(f"Iteration {i}, After Memory Usage: {monitor_memory():.2f} MB")


    cv2.destroyAllWindows()


# Replace with your actual file paths
folder_path = '/home/spot/docker/spot_optik_ctrl/ros2_ws/recorded_data/20250103_1735934820440384621_Sequence'
actual_pose_name = 'actual_poses.npz'
rgb_video_name = 'rgb_video.avi'
hand_video_name = 'rgb_hand_video.avi'

npz_file_path = os.path.join(folder_path, actual_pose_name)
video_file_path = os.path.join(folder_path, hand_video_name)
# Out:
# Iteration 0, Memory Usage: 161247232.00 MB
# before (1018118, 1059054)
# after (1016959, 1059054)
# Iteration 0, After Memory Usage: 161247232.00 MB
# Iteration 10, Memory Usage: 170422272.00 MB
# Iteration 20, Memory Usage: 180424704.00 MB
# Iteration 30, Memory Usage: 189599744.00 MB
# Iteration 40, Memory Usage: 198643712.00 MB
# Iteration 50, Memory Usage: 207818752.00 MB
# Iteration 60, Memory Usage: 217255936.00 MB
# Iteration 70, Memory Usage: 226430976.00 MB
# Iteration 80, Memory Usage: 235737088.00 MB
# Iteration 90, Memory Usage: 244912128.00 MB
# Iteration 100, Memory Usage: 254087168.00 MB
# before (93216273, 93258299)
# after (93213692, 93258299)
# Iteration 100, After Memory Usage: 254087168.00 MB
# Iteration 110, Memory Usage: 263262208.00 MB
# Iteration 120, Memory Usage: 272568320.00 MB
# Iteration 130, Memory Usage: 281743360.00 MB
# Iteration 140, Memory Usage: 290918400.00 MB
# Iteration 150, Memory Usage: 300224512.00 MB
# Iteration 160, Memory Usage: 309399552.00 MB
# Iteration 170, Memory Usage: 318574592.00 MB
# Iteration 180, Memory Usage: 327749632.00 MB
# Iteration 190, Memory Usage: 336924672.00 MB
# Iteration 200, Memory Usage: 346099712.00 MB
# before (185414501, 185456495)
# after (185411092, 185456495)
# Iteration 200, After Memory Usage: 346099712.00 MB
# Iteration 210, Memory Usage: 355405824.00 MB
# Iteration 220, Memory Usage: 364580864.00 MB
# Iteration 230, Memory Usage: 373755904.00 MB
# Iteration 240, Memory Usage: 382930944.00 MB
# Iteration 250, Memory Usage: 392237056.00 MB
# Iteration 260, Memory Usage: 401412096.00 MB
# Iteration 270, Memory Usage: 410587136.00 MB
# Iteration 280, Memory Usage: 419762176.00 MB
# Iteration 290, Memory Usage: 429068288.00 MB
# Iteration 300, Memory Usage: 438374400.00 MB
# before (277611542, 277653568)
# after (277608501, 277653568)
# Iteration 300, After Memory Usage: 438374400.00 MB
# Iteration 310, Memory Usage: 447549440.00 MB
# Iteration 320, Memory Usage: 456724480.00 MB
# Iteration 330, Memory Usage: 466030592.00 MB
# Iteration 340, Memory Usage: 475205632.00 MB
# Iteration 350, Memory Usage: 484380672.00 MB
# Iteration 360, Memory Usage: 493686784.00 MB
# Iteration 370, Memory Usage: 502861824.00 MB
# Iteration 380, Memory Usage: 512036864.00 MB
# Iteration 390, Memory Usage: 521211904.00 MB
# Iteration 400, Memory Usage: 530386944.00 MB
# before (369809345, 369851339)
# after (369805880, 369851339)
# Iteration 400, After Memory Usage: 530386944.00 MB
# Iteration 410, Memory Usage: 539693056.00 MB
# Iteration 420, Memory Usage: 548868096.00 MB
# Iteration 430, Memory Usage: 558043136.00 MB
# Iteration 440, Memory Usage: 567349248.00 MB
# Iteration 450, Memory Usage: 576524288.00 MB
# Iteration 460, Memory Usage: 585699328.00 MB
# Iteration 470, Memory Usage: 594874368.00 MB
# Iteration 480, Memory Usage: 604180480.00 MB
# Iteration 490, Memory Usage: 613355520.00 MB
# Iteration 500, Memory Usage: 622530560.00 MB
# before (462006085, 462048111)
# after (462002956, 462048111)
# Iteration 500, After Memory Usage: 622530560.00 MB
# Iteration 510, Memory Usage: 631967744.00 MB
# Iteration 520, Memory Usage: 641142784.00 MB
# Iteration 530, Memory Usage: 650317824.00 MB
# Iteration 540, Memory Usage: 659492864.00 MB
# Iteration 550, Memory Usage: 668667904.00 MB
# Iteration 560, Memory Usage: 677974016.00 MB
# Iteration 570, Memory Usage: 687149056.00 MB
# Iteration 580, Memory Usage: 696324096.00 MB
# Iteration 590, Memory Usage: 705630208.00 MB
# Iteration 600, Memory Usage: 714805248.00 MB
# before (554203696, 554245722)
# after (554200199, 554245722)
# Iteration 600, After Memory Usage: 714805248.00 MB
# Iteration 610, Memory Usage: 723980288.00 MB
# Iteration 620, Memory Usage: 733286400.00 MB
# Iteration 630, Memory Usage: 742461440.00 MB
# Iteration 640, Memory Usage: 751636480.00 MB
# Iteration 650, Memory Usage: 760942592.00 MB
# Iteration 660, Memory Usage: 769986560.00 MB
# Iteration 670, Memory Usage: 779161600.00 MB
# Iteration 680, Memory Usage: 788467712.00 MB
# Iteration 690, Memory Usage: 797642752.00 MB
# Iteration 700, Memory Usage: 806817792.00 MB
# before (646400773, 646442735)
# after (646397644, 646442735)
# Iteration 700, After Memory Usage: 806817792.00 MB
# Iteration 710, Memory Usage: 816123904.00 MB
# Iteration 720, Memory Usage: 825298944.00 MB
# Iteration 730, Memory Usage: 834473984.00 MB
# Iteration 740, Memory Usage: 843780096.00 MB
# Iteration 750, Memory Usage: 853086208.00 MB
# Iteration 760, Memory Usage: 862261248.00 MB
# Iteration 770, Memory Usage: 871436288.00 MB
# Iteration 780, Memory Usage: 880742400.00 MB
# Iteration 790, Memory Usage: 889917440.00 MB
# Iteration 800, Memory Usage: 899092480.00 MB
# before (738597996, 738640022)
# after (738594499, 738640022)
# Iteration 800, After Memory Usage: 899092480.00 MB
# Iteration 810, Memory Usage: 908267520.00 MB
# Iteration 820, Memory Usage: 917573632.00 MB
# Iteration 830, Memory Usage: 926748672.00 MB
# Iteration 840, Memory Usage: 935923712.00 MB
# Iteration 850, Memory Usage: 945098752.00 MB
# Iteration 860, Memory Usage: 954404864.00 MB
# Iteration 870, Memory Usage: 963579904.00 MB
# Iteration 880, Memory Usage: 972754944.00 MB
# Iteration 890, Memory Usage: 982061056.00 MB
# Iteration 900, Memory Usage: 991236096.00 MB
# before (830795093, 830837055)
# after (830791964, 830837055)
# Iteration 900, After Memory Usage: 991236096.00 MB
# Iteration 910, Memory Usage: 1000411136.00 MB
# Iteration 920, Memory Usage: 1009717248.00 MB
# Iteration 930, Memory Usage: 1018892288.00 MB
# Iteration 940, Memory Usage: 1028067328.00 MB
# Iteration 950, Memory Usage: 1037242368.00 MB
# Iteration 960, Memory Usage: 1046417408.00 MB
# Iteration 970, Memory Usage: 1055723520.00 MB
# Iteration 980, Memory Usage: 1064898560.00 MB
# Iteration 990, Memory Usage: 1074204672.00 MB
# Iteration 1000, Memory Usage: 1083379712.00 MB
# before (922992380, 923033317)
# after (922990378, 923033317)
# Iteration 1000, After Memory Usage: 1083379712.00 MB
# Iteration 1010, Memory Usage: 1092554752.00 MB
# Iteration 1020, Memory Usage: 1101729792.00 MB
# Iteration 1030, Memory Usage: 1111035904.00 MB
# Iteration 1040, Memory Usage: 1120210944.00 MB
# Iteration 1050, Memory Usage: 1129385984.00 MB
# Iteration 1060, Memory Usage: 1138692096.00 MB
# Iteration 1070, Memory Usage: 1147867136.00 MB
# Iteration 1080, Memory Usage: 1157042176.00 MB
# Iteration 1090, Memory Usage: 1166217216.00 MB
# Iteration 1100, Memory Usage: 1175392256.00 MB
# before (1015190281, 1015232306)
# after (1015187163, 1015232306)
# Iteration 1100, After Memory Usage: 1175392256.00 MB
# Iteration 1110, Memory Usage: 1184698368.00 MB
# Iteration 1120, Memory Usage: 1193873408.00 MB

# %%
npz_file_path = os.path.join(folder_path, actual_pose_name)
video_file_path = os.path.join(folder_path, hand_video_name)
datas = []

tracemalloc.start()
loader = lazy_data_loader(npz_file_path, video_file_path)
for i, (timestep, arm_pose, frame) in enumerate(loader):
    
    # Example: Process the frame
    cv2.imshow("Frame", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):  # Press 'q' to quit
        break

    # release the memory
    # it's important for memory release if stored in a list. 
    # if use lazy loaded data with yield, no need for release, as generater do not store data to memory.
    # instead, the data produced by yield is immediately passed to the consumer. 
    # it's up to the caller to store, process and release the memory. 
    # it can be done by set to None, then gc.collect(); 
    # or, by overwriting to the same addr. #
    
    datas.append([timestep, arm_pose, frame])
    # datas[i] = None  
    if i % 10 == 0:  # Check memory every 10 iterations
        print(f"Iteration {i}, Memory Usage: {monitor_memory():.2f} MB")
        # print('monitor', tracemalloc.get_traced_memory())
    
    if i % 100 == 0:
        print('before', tracemalloc.get_traced_memory())
        gc.collect()  # Force garbage collection
        print('after', tracemalloc.get_traced_memory())
        print(f"Iteration {i}, After Memory Usage: {monitor_memory():.2f} MB")


cv2.destroyAllWindows()
tracemalloc.stop()
